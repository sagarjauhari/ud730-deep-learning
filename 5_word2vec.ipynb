# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
words[-10000]
# Out:
# 'from'

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word] 
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'term', 'anarchism', 'a', 'term', 'originated', 'of', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.994433
# Nearest to war: alef, lgpl, panini, counterfeiting, hellenized, quad, geoffrey, paxton,
# Nearest to one: maupassant, drachmae, mascarene, dae, impetus, morita, multistage, apprentices,
# Nearest to had: hepatic, shah, gibson, freed, troubling, usages, fungus, licinius,
# Nearest to of: pompeii, stadiums, mohs, matte, shown, historia, apostle, endeavour,
# Nearest to three: taklamakan, pig, maintainer, cannibalistic, universitaire, overly, demetrius, kellermann,
# Nearest to have: fung, fingerboard, magnesium, sit, noa, expatriates, wildcats, indictees,
# Nearest to from: unrest, hinnom, tut, milk, inserts, progesterone, baer, tea,
# Nearest to by: during, absentee, bernd, desktop, salesman, castration, stirrups, godfather,
# Nearest to such: loft, og, ashford, archives, bloodshed, existent, made, stallions,
# Nearest to were: bundesl, lsd, bournemouth, poudre, valdivia, pushing, ancestor, raped,
# Nearest to seven: multihull, aggravating, ilois, rb, ludvig, spandau, bloodstream, punks,
# Nearest to history: deborah, relatively, muentzer, vez, cheetah, olde, realization, multiplex,
# Nearest to with: backfire, chased, aquifer, keir, cohesive, rh, pegs, salford,
# Nearest to their: attributes, slogan, konrad, faroe, afraid, contributors, stray, taland,
# Nearest to it: metastable, alf, stun, non, yalta, threshold, defectors, spend,
# Nearest to states: dulcimer, almagro, elke, fluctuated, cerf, hofmann, mwali, mithraeum,
# Average loss at step 2000: 4.358329
# Average loss at step 4000: 3.861504
# Average loss at step 6000: 3.793039
# Average loss at step 8000: 3.689602
# Average loss at step 10000: 3.616456
# Nearest to war: fortification, adam, virginian, panini, city, counterfeiting, shirts, shermer,
# Nearest to one: two, oval, six, seven, transmissible, loudness, psychosomatic, eight,
# Nearest to had: has, have, was, saw, were, priori, usages, encapsulated,
# Nearest to of: in, for, at, and, demo, captained, hercule, historia,
# Nearest to three: four, six, five, eight, seven, nine, zero, two,
# Nearest to have: had, be, has, were, are, catchphrase, forester, aegis,
# Nearest to from: in, by, tommy, inserts, into, before, with, baer,
# Nearest to by: was, been, with, in, from, qm, during, absentee,
# Nearest to such: cuba, og, lomax, medicaid, ay, fares, sellers, block,
# Nearest to were: are, was, have, had, vicious, animistic, is, bournemouth,
# Nearest to seven: eight, six, nine, five, four, three, zero, two,
# Nearest to history: muentzer, deborah, relatively, predator, olde, vez, glycol, bible,
# Nearest to with: in, by, between, for, mohel, shab, rudolf, into,
# Nearest to their: his, its, estimated, artery, contributors, bag, attributes, a,
# Nearest to it: he, this, no, there, not, also, never, often,
# Nearest to states: almagro, cerf, elke, tsar, jacketed, coronation, gutman, employers,
# Average loss at step 12000: 3.602912
# Average loss at step 14000: 3.575966
# Average loss at step 16000: 3.406706
# Average loss at step 18000: 3.454792
# Average loss at step 20000: 3.540681
# Nearest to war: adam, shirts, quad, shermer, city, fortification, professor, piraeus,
# Nearest to one: two, four, three, seven, six, five, eight, nine,
# Nearest to had: has, have, was, were, saw, yassir, been, ve,
# Nearest to of: leitrim, in, for, disintegrating, same, hoffman, esv, deficiency,
# Nearest to three: six, four, seven, five, two, eight, zero, nine,
# Nearest to have: had, has, be, were, are, catchphrase, goblins, venetia,
# Nearest to from: into, at, in, through, and, after, shab, by,
# Nearest to by: during, were, be, into, absentee, latest, for, rematch,
# Nearest to such: cuba, well, known, pitched, lomax, block, these, fares,
# Nearest to were: are, was, had, have, be, by, is, been,
# Nearest to seven: eight, six, five, four, nine, three, zero, two,
# Nearest to history: muentzer, bible, bulgaria, predator, development, vez, olde, meath,
# Nearest to with: when, in, for, between, after, into, shab, and,
# Nearest to their: his, its, the, her, brythonic, our, bag, vocational,
# Nearest to it: he, this, there, which, she, not, also, they,
# Nearest to states: elke, coronation, almagro, tsar, employers, kingdom, cerf, collateral,
# Average loss at step 22000: 3.501121
# Average loss at step 24000: 3.492568
# Average loss at step 26000: 3.482951
# Average loss at step 28000: 3.482398
# Average loss at step 30000: 3.500528
# Nearest to war: wy, acadians, friends, paraphrased, fortification, surfer, shirts, ionia,
# Nearest to one: two, seven, four, eight, three, nine, six, five,
# Nearest to had: have, has, was, were, went, priori, saw, animists,
# Nearest to of: in, from, own, navel, including, heinemann, nhl, terrains,
# Nearest to three: four, five, six, seven, eight, two, zero, nine,
# Nearest to have: had, has, were, are, catchphrase, be, never, goblins,
# Nearest to from: into, through, before, in, after, of, shab, under,
# Nearest to by: in, sectarian, was, vulnerabilities, during, under, antacids, principal,
# Nearest to such: well, cuba, these, known, bibles, pitched, sellers, sharing,
# Nearest to were: are, was, have, had, been, those, vicious, mmu,
# Nearest to seven: eight, nine, six, five, four, three, zero, two,
# Nearest to history: development, bulgaria, analysis, deborah, bible, author, muentzer, title,
# Nearest to with: between, under, when, roommate, poulsen, in, for, pork,
# Nearest to their: its, his, her, the, our, some, brythonic, embodies,
# Nearest to it: he, there, this, she, they, also, which, drains,
# Nearest to states: kingdom, coronation, elke, almagro, canonised, tsar, collateral, ivor,
# Average loss at step 32000: 3.502629
# Average loss at step 34000: 3.498306
# Average loss at step 36000: 3.451647
# Average loss at step 38000: 3.299078
# Average loss at step 40000: 3.429761
# Nearest to war: carrero, paraphrased, acadians, ionia, virginian, imt, surfer, lindisfarne,
# Nearest to one: seven, four, two, eight, six, nine, five, three,
# Nearest to had: has, have, was, were, subtle, went, got, been,
# Nearest to of: in, leitrim, from, for, vipassana, definitional, minden, cycladic,
# Nearest to three: four, two, five, six, seven, eight, nine, zero,
# Nearest to have: had, has, were, be, are, venetia, catchphrase, binder,
# Nearest to from: through, into, before, after, biopsy, of, shab, boethius,
# Nearest to by: rhee, sectarian, be, latest, with, vulnerabilities, for, dislodge,
# Nearest to such: well, these, including, known, cuba, other, inductance, sharing,
# Nearest to were: are, have, was, had, epistemological, been, fundy, be,
# Nearest to seven: eight, five, nine, six, four, three, zero, two,
# Nearest to history: deborah, bulgaria, ownership, development, culture, incursion, hanseatic, muentzer,
# Nearest to with: between, mohel, on, donor, when, by, barns, under,
# Nearest to their: its, his, her, the, our, any, brythonic, them,
# Nearest to it: he, there, she, they, this, only, but, not,
# Nearest to states: kingdom, controversy, coronation, supernovae, elke, almagro, hasan, wander,
# Average loss at step 42000: 3.431342
# Average loss at step 44000: 3.453886
# Average loss at step 46000: 3.445368
# Average loss at step 48000: 3.357106
# Average loss at step 50000: 3.379538
# Nearest to war: carrero, surfer, retard, lindisfarne, acadians, virginian, barcode, ionia,
# Nearest to one: two, four, six, eight, seven, three, five, nine,
# Nearest to had: has, have, was, were, having, since, got, ve,
# Nearest to of: and, in, including, roaming, leitrim, vipassana, cycladic, navel,
# Nearest to three: six, four, seven, eight, two, five, nine, zero,
# Nearest to have: had, has, were, be, are, never, catchphrase, goblins,
# Nearest to from: into, through, across, biopsy, in, at, after, before,
# Nearest to by: latest, through, was, during, vulnerabilities, while, under, sectarian,
# Nearest to such: well, these, known, sharing, many, including, cuba, bibles,
# Nearest to were: are, was, have, had, been, be, although, those,
# Nearest to seven: eight, six, nine, four, three, five, two, zero,
# Nearest to history: incursion, ownership, hesychast, sys, deborah, club, roald, culture,
# Nearest to with: between, tolerable, when, lithographic, harassing, extra, via, poulsen,
# Nearest to their: its, his, her, our, the, some, these, several,
# Nearest to it: he, she, there, this, they, now, just, still,
# Nearest to states: kingdom, elke, controversy, almagro, ivor, wander, stratosphere, coronation,
# Average loss at step 52000: 3.436946
# Average loss at step 54000: 3.425773
# Average loss at step 56000: 3.437721
# Average loss at step 58000: 3.392421
# Average loss at step 60000: 3.388426
# Nearest to war: barcode, carrero, ionia, surfer, lindisfarne, fangio, joint, retard,
# Nearest to one: six, eight, four, two, five, three, seven, nine,
# Nearest to had: has, have, was, were, having, got, ve, could,
# Nearest to of: in, for, original, nihilism, same, garbled, eileen, including,
# Nearest to three: five, four, six, eight, two, seven, nine, one,
# Nearest to have: has, had, were, are, be, tend, include, require,
# Nearest to from: into, through, biopsy, across, inserts, before, in, by,
# Nearest to by: through, sectarian, from, under, without, against, vulnerabilities, using,
# Nearest to such: well, known, these, many, including, intercollegiate, sharing, being,
# Nearest to were: are, was, have, although, had, those, while, be,
# Nearest to seven: eight, four, five, six, nine, three, zero, two,
# Nearest to history: bedford, culture, sys, bank, incursion, list, club, bulgaria,
# Nearest to with: between, rh, when, mohel, poulsen, hypocrites, pork, lithographic,
# Nearest to their: its, his, her, our, the, brythonic, eiji, some,
# Nearest to it: he, there, she, this, they, which, now, negated,
# Nearest to states: kingdom, nations, places, state, controversy, elke, hasan, countries,
# Average loss at step 62000: 3.237293
# Average loss at step 64000: 3.253204
# Average loss at step 66000: 3.396461
# Average loss at step 68000: 3.396762
# Average loss at step 70000: 3.354848
# Nearest to war: carrero, lindisfarne, barcode, ionia, acadians, sui, joint, prophecy,
# Nearest to one: two, six, four, eight, seven, five, nine, three,
# Nearest to had: has, have, was, were, having, been, got, never,
# Nearest to of: including, original, include, for, fyodorovna, in, like, leitrim,
# Nearest to three: six, four, two, five, seven, eight, nine, zero,
# Nearest to have: had, has, were, are, be, tend, include, require,
# Nearest to from: through, into, across, between, in, inserts, before, shab,
# Nearest to by: be, using, through, without, rhee, in, latest, macs,
# Nearest to such: these, known, well, including, many, certain, being, fast,
# Nearest to were: are, was, have, had, be, although, including, while,
# Nearest to seven: eight, six, four, nine, five, three, zero, two,
# Nearest to history: list, bedford, period, summary, culture, sys, antipope, hanseatic,
# Nearest to with: between, lithographic, rh, situational, via, otc, into, gabrielle,
# Nearest to their: its, his, her, the, our, your, these, some,
# Nearest to it: he, she, there, this, they, still, which, tique,
# Nearest to states: kingdom, nations, state, countries, hasan, places, glorified, environmentally,
# Average loss at step 72000: 3.372890
# Average loss at step 74000: 3.346884
# Average loss at step 76000: 3.310860
# Average loss at step 78000: 3.345748
# Average loss at step 80000: 3.374078
# Nearest to war: carrero, joint, ionia, archival, syntactical, wars, barcode, acadians,
# Nearest to one: six, seven, two, eight, three, four, five, nine,
# Nearest to had: have, has, were, was, having, began, never, moraines,
# Nearest to of: in, original, hoffman, leitrim, including, navel, cycladic, islington,
# Nearest to three: four, seven, six, five, eight, two, nine, zero,
# Nearest to have: had, has, are, be, were, include, having, get,
# Nearest to from: through, into, across, alfonso, before, after, between, inserts,
# Nearest to by: vulnerabilities, using, through, be, latest, heartbeat, dislodge, and,
# Nearest to such: these, well, known, certain, including, intercollegiate, subconscious, edifices,
# Nearest to were: are, was, had, be, have, been, being, fundy,
# Nearest to seven: eight, five, six, nine, four, three, zero, one,
# Nearest to history: list, sys, antipope, summary, period, rachel, bedford, virtual,
# Nearest to with: between, in, rudolf, roommate, when, pairwise, via, emirs,
# Nearest to their: its, his, her, our, your, my, these, the,
# Nearest to it: he, she, there, this, they, unclear, we, exerting,
# Nearest to states: kingdom, nations, countries, hasan, union, places, coronation, state,
# Average loss at step 82000: 3.405723
# Average loss at step 84000: 3.408279
# Average loss at step 86000: 3.387165
# Average loss at step 88000: 3.350763
# Average loss at step 90000: 3.365266
# Nearest to war: joint, wars, wy, archival, acadians, ionia, carrero, incumbent,
# Nearest to one: seven, two, four, six, eight, five, three, nine,
# Nearest to had: has, have, was, were, having, began, ve, continued,
# Nearest to of: for, toppled, including, in, hoffman, roaming, and, include,
# Nearest to three: four, five, two, seven, eight, six, zero, nine,
# Nearest to have: had, has, were, are, having, require, include, be,
# Nearest to from: through, into, across, towards, between, before, after, within,
# Nearest to by: through, without, using, with, sectarian, under, be, during,
# Nearest to such: known, these, well, certain, including, seen, intercollegiate, rivaled,
# Nearest to were: are, had, was, have, while, although, fundy, these,
# Nearest to seven: eight, six, four, five, nine, three, zero, two,
# Nearest to history: list, period, sys, antipope, bedford, summary, diffusion, vegeta,
# Nearest to with: between, via, by, in, harassing, from, otc, when,
# Nearest to their: its, his, her, our, your, my, the, whose,
# Nearest to it: he, she, there, they, this, exerting, we, unclear,
# Nearest to states: kingdom, nations, us, countries, hasan, union, canonised, state,
# Average loss at step 92000: 3.393805
# Average loss at step 94000: 3.251564
# Average loss at step 96000: 3.352091
# Average loss at step 98000: 3.240459
# Average loss at step 100000: 3.353163
# Nearest to war: joint, wars, wy, trade, archival, ionia, battle, restraint,
# Nearest to one: two, four, seven, five, eight, six, nine, th,
# Nearest to had: has, have, was, having, were, got, since, ve,
# Nearest to of: including, and, in, leitrim, nuova, courageous, hoffman, petitioner,
# Nearest to three: five, two, six, seven, four, eight, nine, zero,
# Nearest to have: had, has, are, were, provide, be, having, tend,
# Nearest to from: through, into, in, across, biopsy, helens, towards, ultraviolet,
# Nearest to by: through, without, including, vulnerabilities, tra, when, were, be,
# Nearest to such: known, these, well, including, certain, many, intercollegiate, sharing,
# Nearest to were: are, was, have, had, those, these, although, fundy,
# Nearest to seven: eight, six, five, four, nine, three, zero, two,
# Nearest to history: list, diffusion, sys, antipope, transformation, panhandle, period, ploy,
# Nearest to with: between, via, when, moneo, religiously, harassing, vipassana, roommate,
# Nearest to their: its, his, her, our, your, the, these, whose,
# Nearest to it: he, she, this, there, they, unclear, exerting, often,
# Nearest to states: nations, kingdom, us, hasan, countries, union, almohades, shenandoah,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
